# %% [markdown]
# ## CardioVascular Disease Predication

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from kmodes.kmodes import KModes

# %%
df=pd.read_csv("cardio_train.csv",delimiter=';')
df.drop(columns='id', inplace=True)

# %%
df.head()
# Out:
#      age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0  22469       1     155    69.0    130     80            2     2      0
# 1  14648       1     163    71.0    110     70            1     1      0
# 2  21901       1     165    70.0    120     80            1     1      0
# 3  14549       2     165    85.0    120     80            1     1      1
# 4  23393       1     155    62.0    120     80            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       1       0
# 3     1       1       0
# 4     0       1       0

# %%
df["age"] = df["age"]/365
df.shape
# Out:
# (69301, 12)

# %%
numeric_cols = ['height', 'weight', 'ap_hi', 'ap_lo']

plt.figure(figsize=(14, 8))

# Create a boxplot for each numeric column
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
numeric_cols = ['height', 'weight', 'ap_hi', 'ap_lo']

# Remove outliers outside the 2.5% to 97.5% quantiles
for col in numeric_cols:
    lower = df[col].quantile(0.025)
    upper = df[col].quantile(0.975)
    df = df[(df[col] >= lower) & (df[col] <= upper)]
    
df.shape
# Out:
# (59555, 12)

# %% [markdown]
# ### Feature Reducion

# %% [markdown]
# ##### Convering Age into bins

# %%
bins = [29, 35, 40, 45, 50, 55, 60, 65]  # Upper bound is exclusive
# labels = ["30-35", "35-40", "40-45", "45-50", "50-55", "55-60", "60-65"]
labels= [0, 1, 2, 3, 4, 5, 6]
df["Age_class"] = pd.cut(df["age"], bins=bins, labels=labels, right=False)

# %% [markdown]
# ##### Calculating BMI and creating bins of BMI

# %%
df["height"] = df["height"] / 100  # Convert height from cm to meters
df["BMI"] = df["weight"] / (df["height"] ** 2)

# %%
df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  59555.000000  59555.000000  59555.000000  59555.000000  59555.000000
# mean      53.337993      1.347276      1.645567     73.421721    125.763832
# std        6.741379      0.476108      0.068300     11.609272     13.760110
# min       29.583562      1.000000      1.500000     52.000000    100.000000
# 25%       48.427397      1.000000      1.600000     65.000000    120.000000
# 50%       53.986301      1.000000      1.650000     72.000000    120.000000
# 75%       58.412329      2.000000      1.690000     80.000000    135.000000
# max       64.967123      2.000000      1.800000    106.000000    162.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  59555.000000  59555.000000  59555.000000  59555.000000  59555.000000
# mean      81.043674      1.350785      1.220217      0.085568      0.051986
# std        8.236916      0.670012      0.567605      0.279727      0.222000
# min       60.000000      1.000000      1.000000      0.000000      0.000000
# 25%       80.000000      1.000000      1.000000      0.000000      0.000000
# 50%       80.000000      1.000000      1.000000      0.000000      0.000000
# 75%       90.000000      1.000000      1.000000      0.000000      0.000000
# max      100.000000      3.000000      3.000000      1.000000      1.000000
#
#              active        cardio           BMI
# count  59555.000000  59555.000000  59555.000000
# mean       0.803896      0.488036     27.168340
# std        0.397052      0.499861      4.403805
# min        0.000000      0.000000     16.049383
# 25%        1.000000      0.000000     23.875115
# 50%        1.000000      0.000000     26.259585
# 75%        1.000000      1.000000     29.752066
# max        1.000000      1.000000     46.666667

# %%
bins = [15, 20, 25, 30, 35, 40, 45, 50]  # Upper bound is exclusive
# # labels = ["15-20", "20-25", "25-30", "30-35", "35-40", "40-45", "45-50","50-55"]
labels=[0, 1, 2, 3, 4, 5, 6]

df["BMI_class"] = pd.cut(df["BMI"], bins=bins, labels=labels, right=False)
df = df.drop(columns=["BMI"])

# %%
df.isna().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# Age_class      0
# BMI_class      0
# dtype: int64

# %%
df["map"] = (2*df["ap_lo"] + df["ap_hi"])/3

# %%
df["map"].describe()
# Out:
# count    59555.000000
# mean        95.950393
# std          9.286019
# min         73.333333
# 25%         93.333333
# 50%         93.333333
# 75%        103.333333
# max        120.000000
# Name: map, dtype: float64

# %%
bins = [70, 80, 90, 100,110,121]  # Upper bound is exclusive
# labels = ["70-80", "80-90", "90-100", "100-110","110-120"]
labels=[0, 1, 2, 3, 4]

df["MAP_class"] = pd.cut(df["map"], bins=bins, labels=labels, right=False)
df = df.drop(columns=["map"])

# %%
df.head()
# Out:
#    gender  cholesterol  gluc  smoke  alco  active  cardio Age_class BMI_class  \
# 0       1            2     2      0     0       1       0         6         2
# 1       1            1     1      0     0       1       1         2         2
# 2       1            1     1      0     0       1       0         6         2
# 3       2            1     1      1     1       1       0         1         3
# 4       1            1     1      0     0       1       0         6         2
#
#   MAP_class  cluster
# 0         2        0
# 1         1        0
# 2         2        0
# 3         2        1
# 4         2        0

# %%
df = df.drop(columns=["age"])
df = df.drop(columns=["ap_lo"])
df = df.drop(columns=["ap_hi"])
df = df.drop(columns=["height"])
df = df.drop(columns=["weight"])

# %%
df.head()
# Out:
#    gender  cholesterol  gluc  smoke  alco  active  cardio Age_class BMI_class  \
# 0       1            2     2      0     0       1       0         6         2
# 1       1            1     1      0     0       1       1         2         2
# 2       1            1     1      0     0       1       0         6         2
# 3       2            1     1      1     1       1       0         1         3
# 4       1            1     1      0     0       1       0         6         2
#
#   MAP_class
# 0         2
# 1         1
# 2         2
# 3         2
# 4         2

# %% [markdown]
# ### Clustering

# %%
categorical_columns = ['gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 
                       'cardio', 'Age_class', 'BMI_class', 'MAP_class']

# Extract categorical data
cat_data = df[categorical_columns]

# Initialize K-Modes (choose number of clusters, e.g., 3)
km = KModes(n_clusters=2, init='Huang', n_init=5, verbose=1)

# Fit the model and get cluster labels
clusters = km.fit_predict(cat_data)

# Add cluster labels to your original DataFrame
df['cluster'] = clusters
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 4439, cost: 184323.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 15872, cost: 171645.0
# Run 2, iteration: 2/100, moves: 6175, cost: 171645.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 10242, cost: 174946.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 13975, cost: 168395.0
# Run 4, iteration: 2/100, moves: 955, cost: 168395.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 11841, cost: 166137.0
# Best run was number 5

# %%
corr_matrix = df.corr()

plt.figure(figsize=(14, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
df_male = df[df["gender"]==1]
df_female = df[df["gender"]==2]

# %%
df_male.shape[0] + df_female.shape[0]
# Out:
# 59555

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Descision Tree

# %%
inputs = df_male.drop('cardio',axis='columns')

target=df_male["cardio"]
X_train,X_test,Y_train,Y_test=train_test_split(inputs,target,test_size=0.2)

# %%
X_train.head()
# Out:
#        gender  cholesterol  gluc  smoke  alco  active Age_class BMI_class  \
# 8453        1            1     1      0     0       1         6         2
# 13304       1            3     1      0     0       1         6         2
# 765         1            2     1      0     0       1         5         3
# 47946       1            1     1      0     0       1         5         4
# 58655       1            1     1      0     0       0         4         1
#
#       MAP_class  cluster
# 8453          2        0
# 13304         2        0
# 765           3        0
# 47946         3        0
# 58655         2        1

# %%
from sklearn import tree
model=tree.DecisionTreeClassifier()

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test,Y_test)
# Out:
# 0.8688102893890676

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report, accuracy_score
Y_pred = rf.predict(X_test)
print("Accuracy:", accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.8698392282958199

# %% [markdown]
# ### XG Boost

# %%
from xgboost import XGBClassifier
xg = XGBClassifier(use_label_encoder=False, eval_metric='logloss',enable_categorical=True, eta=0.01)
xg.fit(X_train, Y_train)
# Out:
# C:\Users\rajar\anaconda3\Lib\site-packages\xgboost\training.py:183: UserWarning: [15:54:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eta=0.01, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None, ...)

# %%
Y_pred = xg.predict(X_test)

# %%
print("Accuracy:", accuracy_score(Y_test, Y_pred))
# print("\nClassification Report:\n", classification_report(Y_test, Y_pred))
# Out:
# Accuracy: 0.8734405144694534

# %% [markdown]
# ### MLP

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(
    hidden_layer_sizes=(128, 64),
    activation='relu',
    solver='adam',
    learning_rate_init=0.01,
    alpha=0.0001,
    early_stopping=True,
    validation_fraction=0.1,
    max_iter=500,
    random_state=42
)
mlp.fit(X_train, Y_train)
# Out:
# MLPClassifier(early_stopping=True, hidden_layer_sizes=(128, 64),
#               learning_rate_init=0.01, max_iter=500, random_state=42)

# %%
Y_pred = mlp.predict(X_test)

# %%
print("Accuracy:", accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.8697106109324759

# %% [markdown]
# #### MLP with GridSearchCV

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

# Define the base model
mlp = MLPClassifier(
    early_stopping=True,
    validation_fraction=0.1,
    max_iter=500,
    random_state=42
)

# Define parameter grid
param_grid = {
    'hidden_layer_sizes': [(64,), (128,), (128, 64), (128, 64, 32)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam'],
    'learning_rate_init': [0.001, 0.01],
    'alpha': [0.0001, 0.001],  # L2 regularization
}

# Setup GridSearchCV
grid = GridSearchCV(
    mlp,
    param_grid,
    scoring='accuracy',
    cv=5,
    n_jobs=-1,
    verbose=1
)

# Fit the model
grid.fit(X_train, Y_train)

# Print results
print("✅ Best Accuracy:", grid.best_score_)
print("🏆 Best Params:", grid.best_params_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# ✅ Best Accuracy: 0.8692195734573389
# 🏆 Best Params: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate_init': 0.01, 'solver': 'adam'}

# %% [markdown]
# ### LGBM

# %%
import lightgbm as lgb

# %%
train_data = lgb.Dataset(X_train, label=Y_train, categorical_feature='auto')
test_data = lgb.Dataset(X_test, label=Y_test, categorical_feature='auto')


params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'verbose': -1
}
num_round = 1000
bst = lgb.train(params, train_data, num_round, valid_sets=[
                test_data])

# %%
y_pred_probs = model.predict(X_test)         # Probabilities
y_pred = (y_pred_probs > 0.5).astype(int)     # Convert to class labels

from sklearn.metrics import accuracy_score
acc = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {acc:.4f}")
# Out:
# Accuracy: 0.8728

# %% [markdown]
# ### After Hyper Parameter tunning

# %%
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMClassifier
params = {
    'num_leaves': [31, 50, 70, 100],
    'max_depth': [-1, 10, 20, 30],
    'learning_rate': [0.1, 0.05, 0.01, 0.005],
    'n_estimators': [100, 300, 500],
    'min_child_samples': [10, 20, 30],  # Controls overfitting
    'subsample': [0.6, 0.8, 1.0],       # Row sampling
    'colsample_bytree': [0.6, 0.8, 1.0], # Feature sampling
    'reg_alpha': [0, 0.1, 0.5],         # L1 regularization
    'reg_lambda': [0, 0.1, 0.5]         # L2 regularization
}

model = LGBMClassifier()
grid = GridSearchCV(model, params, scoring='accuracy', cv=5)
grid.fit(X_train, Y_train, categorical_feature=['gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'Age_class', 'BMI_class', 'MAP_class'])

print("Best accuracy:", grid.best_score_)
print("Best params:", grid.best_params_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[134], line 17
#      15 model = LGBMClassifier()
#      16 grid = GridSearchCV(model, params, scoring='accuracy', cv=5)
# ---> 17 grid.fit(X_train, Y_train, categorical_feature=['gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'Age_class', 'BMI_class', 'MAP_class'])
#      19 print("Best accuracy:", grid.best_score_)
#      20 print("Best params:", grid.best_params_)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1527, in GridSearchCV._run_search(self, evaluate_candidates)
#    1525 def _run_search(self, evaluate_candidates):
#    1526     """Search all candidates in param_grid"""
# -> 1527     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:916, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
# --> 916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
#     928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\anaconda3\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py:129, in _FuncWrapper.__call__(self, *args, **kwargs)
#     127     config = {}
#     128 with config_context(**config):
# --> 129     return self.function(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:895, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     893         estimator.fit(X_train, **fit_params)
#     894     else:
# --> 895         estimator.fit(X_train, y_train, **fit_params)
#     897 except Exception:
#     898     # Note fit time as time until error
#     899     fit_time = time.time() - start_time
#
# File ~\anaconda3\Lib\site-packages\lightgbm\sklearn.py:1560, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1557         else:
#    1558             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1560 super().fit(
#    1561     X,
#    1562     _y,
#    1563     sample_weight=sample_weight,
#    1564     init_score=init_score,
#    1565     eval_set=valid_sets,
#    1566     eval_names=eval_names,
#    1567     eval_sample_weight=eval_sample_weight,
#    1568     eval_class_weight=eval_class_weight,
#    1569     eval_init_score=eval_init_score,
#    1570     eval_metric=eval_metric,
#    1571     feature_name=feature_name,
#    1572     categorical_feature=categorical_feature,
#    1573     callbacks=callbacks,
#    1574     init_model=init_model,
#    1575 )
#    1576 return self
#
# File ~\anaconda3\Lib\site-packages\lightgbm\sklearn.py:1049, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1046 evals_result: _EvalResultDict = {}
#    1047 callbacks.append(record_evaluation(evals_result))
# -> 1049 self._Booster = train(
#    1050     params=params,
#    1051     train_set=train_set,
#    1052     num_boost_round=self.n_estimators,
#    1053     valid_sets=valid_sets,
#    1054     valid_names=eval_names,
#    1055     feval=eval_metrics_callable,  # type: ignore[arg-type]
#    1056     init_model=init_model,
#    1057     callbacks=callbacks,
#    1058 )
#    1060 # This populates the property self.n_features_, the number of features in the fitted model,
#    1061 # and so should only be set after fitting.
#    1062 #
#    1063 # The related property self._n_features_in, which populates self.n_features_in_,
#    1064 # is set BEFORE fitting.
#    1065 self._n_features = self._Booster.num_feature()
#
# File ~\anaconda3\Lib\site-packages\lightgbm\engine.py:350, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     348     booster.best_score[dataset_name][eval_name] = score
#     349 if not keep_training_booster:
# --> 350     booster.model_from_string(booster.model_to_string()).free_dataset()
#     351 return booster
#
# File ~\anaconda3\Lib\site-packages\lightgbm\basic.py:4592, in Booster.model_to_string(self, num_iteration, start_iteration, importance_type)
#    4589 string_buffer = ctypes.create_string_buffer(buffer_len)
#    4590 ptr_string_buffer = ctypes.c_char_p(ctypes.addressof(string_buffer))
#    4591 _safe_call(
# -> 4592     _LIB.LGBM_BoosterSaveModelToString(
#    4593         self._handle,
#    4594         ctypes.c_int(start_iteration),
#    4595         ctypes.c_int(num_iteration),
#    4596         ctypes.c_int(importance_type_int),
#    4597         ctypes.c_int64(buffer_len),
#    4598         ctypes.byref(tmp_out_len),
#    4599         ptr_string_buffer,
#    4600     )
#    4601 )
#    4602 actual_len = tmp_out_len.value
#    4603 # if buffer length is not long enough, re-allocate a buffer
#
# KeyboardInterrupt:

# %% [markdown]
# ### CatBoost

# %%
from catboost import CatBoostClassifier

# Define categorical features (as indices)
cat_features = [X_train.columns.get_loc(col) for col in [
    'gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'Age_class', 'BMI_class', 'MAP_class'
]]

# Initialize CatBoostClassifier with default parameters
model = CatBoostClassifier(verbose=0, random_state=42)

# Train the model
model.fit(X_train, Y_train, cat_features=cat_features)

# %%
# Predict and evaluate
y_pred = model.predict(X_test)
acc = accuracy_score(Y_test, y_pred)
print(f"CatBoost Accuracy: {acc:.4f}")
# Out:
# CatBoost Accuracy: 0.8722

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV
import pandas as pd

# Define the model
model = CatBoostClassifier(verbose=0, random_state=42)
cat_features = list(range(X_train.shape[1]))
# Grid parameters (small for demo, expand for real case)
params = {
    'depth': [4, 6],
    'learning_rate': [0.05, 0.1],
    'iterations': [100, 200],
}

# Grid search with CatBoost
grid = GridSearchCV(model, params, scoring='accuracy', cv=3, n_jobs=-1, verbose=1)

# Fit the model (CatBoost handles categorical indices internally)
grid.fit(X_train, Y_train, cat_features=cat_features)

# Print best results
print("✅ Best Accuracy:", grid.best_score_)
print("🏆 Best Params:", grid.best_params_)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# ✅ Best Accuracy: 0.8712457392758376
# 🏆 Best Params: {'depth': 6, 'iterations': 200, 'learning_rate': 0.1}
